# %% [markdown]
# # Publication notebook: baseline classical metrics
#
# - Purpose: inspect the retained baseline pair-noq classical metrics.
# - Required inputs: `results/metrics/classical/baseline_pair_noq/metrics_summary.tsv`.
# - Required models: none.
# - Required external tools: none.
# - Expected outputs: baseline comparison plots.
# - Publication output: baseline model ranking figures.
# - Reproduction status: expected to run from tracked metrics; not rerun here.

# %%
import pandas as pd
import matplotlib.pyplot as plt

metrics = pd.read_csv("../results/metrics/classical/baseline_pair_noq/metrics_summary.tsv", sep="\t")
metrics

# %%
metrics_sorted = metrics.sort_values("test_f1", ascending=False).reset_index(drop=True)
metrics_sorted

# %%
plt.figure(figsize=(7, 4))
plt.barh(metrics_sorted["model"], metrics_sorted["test_f1"])
plt.xlabel("Test F1")
plt.title("Baseline models (PAIR_noq)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()

# %%
metrics_auc = metrics.sort_values("test_roc_auc", ascending=False).reset_index(drop=True)

plt.figure(figsize=(7, 4))
plt.barh(metrics_auc["model"], metrics_auc["test_roc_auc"])
plt.xlabel("Test ROC-AUC")
plt.title("Baseline ROC-AUC (PAIR_noq)")
plt.gca().invert_yaxis()
plt.tight_layout()
plt.show()
